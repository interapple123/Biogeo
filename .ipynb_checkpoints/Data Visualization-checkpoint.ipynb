# %%
import xarray as xr

# %%
dataspath = './'

# %%
ds = xr.open_dataset(dataspath + 'PTRACER01.nc')

# %%
ds
# Out:
# <xarray.Dataset> Size: 3MB
# Dimensions:    (XC: 128, YC: 64, XG: 128, YG: 64, Z: 15, Zp1: 16, Zu: 15,
#                 Zl: 15, time: 2)
# Coordinates: (12/34)
#   * XC         (XC) float32 512B 1.406 4.219 7.031 9.844 ... 353.0 355.8 358.6
#   * YC         (YC) float32 256B -88.59 -85.78 -82.97 ... 82.97 85.78 88.59
#   * XG         (XG) float32 512B 0.0 2.812 5.625 8.438 ... 351.6 354.4 357.2
#   * YG         (YG) float32 256B -90.0 -87.19 -84.38 ... 81.56 84.38 87.19
#   * Z          (Z) float32 60B -25.0 -85.0 -170.0 ... -4.19e+03 -4.855e+03
#   * Zp1        (Zp1) float32 64B 0.0 -50.0 -120.0 ... -4.51e+03 -5.2e+03
#     ...         ...
#     rhoRef     (Z) float32 60B ...
#     dxF        (YC, XC) float32 33kB ...
#     dxV        (YG, XG) float32 33kB ...
#     dyF        (YC, XC) float32 33kB ...
#     iter       (time) int64 16B ...
#   * time       (time) timedelta64[ns] 16B 54000 days 54000 days 01:00:00
# Data variables:
# ...

# %%
ds.PTRACER01
# Out:
# <xarray.DataArray 'PTRACER01' (time: 2, Z: 15, YC: 64, XC: 128)> Size: 983kB
# [245760 values with dtype=float32]
# Coordinates: (12/14)
#   * XC       (XC) float32 512B 1.406 4.219 7.031 9.844 ... 353.0 355.8 358.6
#   * YC       (YC) float32 256B -88.59 -85.78 -82.97 -80.16 ... 82.97 85.78 88.59
#   * Z        (Z) float32 60B -25.0 -85.0 -170.0 ... -4.19e+03 -4.855e+03
#     rA       (YC, XC) float32 33kB ...
#     Depth    (YC, XC) float32 33kB ...
#     drF      (Z) float32 60B ...
#     ...       ...
#     maskC    (Z, YC, XC) bool 123kB ...
#     rhoRef   (Z) float32 60B ...
#     dxF      (YC, XC) float32 33kB ...
#     dyF      (YC, XC) float32 33kB ...
#     iter     (time) int64 16B ...
#   * time     (time) timedelta64[ns] 16B 54000 days 54000 days 01:00:00
# Attributes:
#     standard_name:  PTRACER01_concentration
#     long_name:      Concentration of PTRACER01
#     units:          kg m-3

# %%
dic = ds['PTRACER01']

# %%
ts = dic.sel(YC=[-88.59, -85.78], XC=1.406, Z=-0.5, method="nearest")
ts.plot.line(x='time')
